# %%
# 1. Attiva l'autoreload per ricaricare in automatico i moduli .py modificati
#%load_ext autoreload
#%autoreload 2

import os
from pathlib import Path

# ==========================================
# CONFIGURAZIONE REPOSITORY
# ==========================================
REPO_URL = "https://github.com/MatteoSanna23/MultimodalSystemSportsInjury.git"
REPO_NAME = "MultimodalSystemSportsInjury"

# 2. Clonazione o Aggiornamento automatico
if not Path(f"/content/{REPO_NAME}").exists():
    print("🚀 Prima esecuzione: Clonando il repository da GitHub...")
    # !git clone {REPO_URL}
else:
    print("🔄 Repository già presente: Scarico gli ultimi aggiornamenti (git pull)...")
    # !git -C /content/{REPO_NAME} pull

# 3. Spostati dentro la cartella del repo appena scaricata
# %cd /content/{REPO_NAME}

print(f"📍 Directory corrente di lavoro: {os.getcwd()}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_591/2350395480.py in <cell line: 0>()
#       1 # 1. Attiva l'autoreload per ricaricare in automatico i moduli .py modificati
# ----> 2 get_ipython().run_line_magic('load_ext', 'autoreload')
#       3 get_ipython().run_line_magic('autoreload', '2')
#       4
#       5 import os
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-57> in load_ext(self, module_str)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/extension.py in load_ext(self, module_str)
#      31         if not module_str:
#      32             raise UsageError('Missing module name.')
# ---> 33         res = self.shell.extension_manager.load_extension(module_str)
#      34
#      35         if res == 'already loaded':
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/extensions.py in load_extension(self, module_str)
#      78             if module_str not in sys.modules:
#      79                 with prepended_to_syspath(self.ipython_extension_dir):
# ---> 80                     mod = import_module(module_str)
#      81                     if mod.__file__.startswith(self.ipython_extension_dir):
#      82                         print(("Loading extensions from {dir} is deprecated. "
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.12/dist-packages/IPython/extensions/autoreload.py in <module>
#     119 from importlib import import_module
#     120 from importlib.util import source_from_cache
# --> 121 from imp import reload
#     122
#     123 #------------------------------------------------------------------------------
#
# ModuleNotFoundError: No module named 'imp'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Il tuo script 'main_lstm.py' cerca il file CSV al percorso: '..//multimodal_sports_injury_dataset.csv'
# Questo significa che cerca il file un livello sopra la cartella del progetto (ovvero direttamente in /content/)

dataset_path = Path('/content/multimodal_sports_injury_dataset.csv')

if not dataset_path.exists():
    print("⚠️ ATTENZIONE: Il file CSV non è stato trovato!")
    print("Trascina 'multimodal_sports_injury_dataset.csv' direttamente nella cartella root '/content/' dall'Esplora Risorse di VS Code, poi esegui la cella successiva.")
else:
    print("✅ Dataset trovato correttamente in /content/. Puoi far partire il training!")

# %%
# Lancia l'intero script di addestramento sfruttando la GPU di Colab
# %run main_lstm.py
